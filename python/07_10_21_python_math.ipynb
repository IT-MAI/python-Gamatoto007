# %%
q=0
for i in range(1,5):
    q+=3*i
print("Ответ: " + str(q))
# Out:
# Ответ: 30

# %%
q=1
for i in range(1,5):
    q*=2*i
print("Ответ: " + str(q))
# Out:
# Ответ: 384

# %%
def aboba (x):
    return (x+2)
S = aboba (x)
array=[aboba(x) for x in range (-1000,1000)]
import matplotlib.pyplot as plt
plt.plot(array)

# %%
def aboba (x):
    return (x**2+2)
S = aboba (x)
array=[aboba(x) for x in range (-1000,1000)]
import matplotlib.pyplot as plt
plt.plot(array)

# %%
def aboba (x):
    return (x**3)
S = aboba (x)
array=[aboba(x) for x in range (-1000,1000)]
import matplotlib.pyplot as plt
plt.plot(array)

# %%
import math
import numpy as np

# %%
np.arange(0, math.pi, 0.0001)
# Out:
# array([0.0000e+00, 1.0000e-04, 2.0000e-04, ..., 3.1413e+00, 3.1414e+00,
#        3.1415e+00])

# %%
def aboba (x): 
    return math.sin(x)*(math.sqrt(np.abs(math.cos(x))))/(math.sin(x)+7/5)-2*math.sin(x)+2
array=[aboba(x) for x in np.arange (0, math.pi, 0.0001)]
import matplotlib.pyplot as plt
plt.plot(np.arange , array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10468/2443735175.py in <module>
#       3 array=[aboba(x) for x in np.arange (0, math.pi, 0.0001)]
#       4 import matplotlib.pyplot as plt
# ----> 5 plt.plot(np.arange , array)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...
